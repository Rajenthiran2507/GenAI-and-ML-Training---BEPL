# %% [markdown]
# # 🛠️ Notebook 2: Hands-on Prompting Lab
# ## Building Prompt Variants & Experimenting with Techniques
#
# **What you'll do:**
# - Build and iterate on prompts for real tasks
# - Compare variant outputs side-by-side
# - Experiment with temperature, system prompts, and formatting
# - Create a prompt engineering toolkit
#
# **Model:** `gpt-4o-mini` | **Embeddings:** `text-embedding-3-small`
#
# ---

# %%
# ============================================
# 📦 Setup
# ============================================
# !pip install openai tiktoken rich numpy -q

import os, json, time, textwrap
from getpass import getpass
from openai import OpenAI
import numpy as np
from IPython.display import display, HTML, Markdown as IPyMarkdown

# os.environ["OPENAI_API_KEY"] = getpass("🔑 Enter your OpenAI API key: ")
# Load API key from Colab Secrets
from google.colab import userdata
import openai

OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
client = openai.OpenAI(api_key=OPENAI_API_KEY)

MODEL = "gpt-4o-mini"
EMBED_MODEL = "text-embedding-3-small"

def chat(messages, temperature=0.7, max_tokens=1024):
    r = client.chat.completions.create(model=MODEL, messages=messages, temperature=temperature, max_tokens=max_tokens)
    return r.choices[0].message.content

def embed(text):
    r = client.embeddings.create(model=EMBED_MODEL, input=text)
    return r.data[0].embedding

def compare_prompts(prompts_dict, temperature=0.5):
    """Run multiple prompts and display results side by side."""
    results = {}
    for name, msgs in prompts_dict.items():
        if isinstance(msgs, str):
            msgs = [{"role": "user", "content": msgs}]
        results[name] = chat(msgs, temperature=temperature)

    for name, result in results.items():
        display(IPyMarkdown(f"### 🔹 {name}\n---\n{result}\n"))
    return results

print("✅ Ready! Let's build some prompts.")
# Out:
# ✅ Ready! Let's build some prompts.

# %% [markdown]
# ---
# ## 🧪 Lab 1: The Prompt Anatomy Workshop
#
# Every effective prompt has building blocks. Let's dissect and build them systematically.

# %%
# ============================================
# 🔬 Lab 1.1: Deconstructing a Prompt
# ============================================

# We'll build the SAME task with increasing prompt sophistication
task = "Write a product description for a smart water bottle that tracks hydration."

# Level 1: Bare minimum
level1 = task

# Level 2: Add context + constraints
level2 = f"""You are a senior copywriter at a DTC e-commerce brand.

{task}

Requirements:
- Target audience: health-conscious millennials
- Tone: friendly but premium
- Length: 80-100 words
- Include a call-to-action"""

# Level 3: Add examples + structure
level3 = f"""You are a senior copywriter at a DTC e-commerce brand known for witty,
benefit-driven copy.

Here's an example of our brand voice:
"Your morning coffee deserves better than a paper cup. Meet ThermoLux —
12 hours hot, 24 hours cold, infinite style points. ☕"

Now {task.lower()}

Format:
**Headline:** [punchy, under 8 words]
**Body:** [80-100 words, benefit-focused, conversational]
**CTA:** [action-oriented button text]

Constraints:
- Target: health-conscious millennials (25-35)
- Avoid: jargon, clichés like "game-changer" or "revolutionary"
- Must mention: the app integration feature"""

# Level 4: Add persona + anti-patterns + scoring criteria
level4 = f"""<role>Senior copywriter at HydroTech, a premium DTC wellness brand.
Your copy has won 3 Webby Awards. You write like Apple meets Glossier.</role>

<task>{task}</task>

<brand_voice_examples>
GOOD: "Your morning coffee deserves better than a paper cup. Meet ThermoLux — 12 hours hot, 24 hours cold, infinite style points."
GOOD: "Track every sip. Crush every goal. Look good doing it."
BAD: "This revolutionary game-changing bottle will transform your hydration journey."
BAD: "Buy now and experience the future of drinking water."
</brand_voice_examples>

<output_format>
**Headline:** [punchy, under 8 words, no clichés]
**Subheadline:** [benefit-driven, 10-15 words]
**Body:** [80-100 words]
**CTA Button:** [3-5 words, action-oriented]
**Meta Description:** [under 155 characters for SEO]
</output_format>

<constraints>
- Target: health-conscious millennials (25-35)
- MUST mention: app sync, daily goal tracking, premium materials
- AVOID: "revolutionary", "game-changer", "transform", "journey", exclamation marks
- Tone: confident, warm, slightly playful
</constraints>

<scoring_criteria>
Rate your own output 1-5 on: Clarity, Brand Fit, Persuasion, Originality
If any score < 4, revise before submitting.
</scoring_criteria>"""

results = compare_prompts({
    "Level 1 — Bare Minimum": level1,
    "Level 2 — Context + Constraints": level2,
    "Level 3 — Examples + Structure": level3,
    "Level 4 — Full Framework": level4
}, temperature=0.5)
# Out:
# ### 🔹 Level 1 — Bare Minimum
# ---
# **Introducing the AquaTrack Smart Water Bottle: Your Ultimate Hydration Companion**
#
# Stay hydrated and elevate your wellness journey with the AquaTrack Smart Water Bottle, the perfect blend of cutting-edge technology and sleek design. Engineered for those who prioritize health and efficiency, this innovative water bottle ensures you never miss a sip while keeping you informed about your hydration habits.
#
# **Key Features:**
#
# - **Hydration Tracking:** The AquaTrack features an advanced sensor that accurately monitors your water intake throughout the day. Sync it with our user-friendly mobile app for real-time updates and personalized hydration goals tailored to your lifestyle.
#
# - **Smart Notifications:** Receive gentle reminders and notifications on your smartphone or through the bottle's LED display, encouraging you to drink water at regular intervals. Say goodbye to dehydration and hello to a healthier you!
#
# - **Sleek and Durable Design:** Crafted from high-quality, BPA-free stainless steel, the AquaTrack is designed to withstand your active lifestyle. Its double-walled insulation keeps your beverages cold for up to 24 hours or hot for up to 12 hours, making it perfect for any occasion.
#
# - **Customizable Goals:** Whether you’re an athlete, a busy professional, or simply looking to improve your daily water intake, the AquaTrack app allows you to set and adjust hydration goals based on your personal needs.
#
# - **Easy to Clean:** The wide-mouth opening makes filling and cleaning a breeze, while the detachable base allows for easy access to the smart tracking components.
#
# - **Long-Lasting Battery:** With a rechargeable battery that lasts up to two weeks on a single charge, the AquaTrack ensures you stay connected without the hassle of frequent charging.
#
# **Why Choose AquaTrack?**
#
# Hydration is key to maintaining energy levels, improving concentration, and enhancing overall health. The AquaTrack Smart Water Bottle empowers you to take control of your hydration habits, making it easier than ever to reach your daily water intake goals. Whether you're hitting the gym, heading to the office, or exploring the great outdoors, AquaTrack is your reliable partner in hydration.
#
# **Join the hydration revolution today!** Experience the future of drinking water with the AquaTrack Smart Water Bottle – because every sip counts!
# ### 🔹 Level 2 — Context + Constraints
# ---
# Introducing the HydratePro Smart Water Bottle – your ultimate hydration companion! Designed for health-conscious millennials, this sleek, BPA-free bottle not only keeps your drinks cool but also tracks your daily water intake with precision. With its easy-to-use app, set personalized hydration goals and receive gentle reminders to sip throughout the day. The modern design fits seamlessly into your active lifestyle, whether you're at the gym, in the office, or on-the-go. Elevate your hydration game and feel your best. Ready to make every sip count? Grab your HydratePro today and stay refreshed!
# ### 🔹 Level 3 — Examples + Structure
# ---
# **Headline:** Stay Hydrated, Stay Awesome
#
# **Body:** Meet AquaSync — the smart water bottle that’s more than just a pretty face. With its sleek design and hydration tracking, you’ll never forget to sip again. Sync it with our app to get personalized reminders and track your daily intake like a hydration pro. Plus, it keeps your drink hot or cold for hours, so you can hydrate in style, whether you’re at the gym or on the go. Say goodbye to dehydration and hello to your new hydration buddy!
#
# **CTA:** Quench Your Thirst Now!
# ### 🔹 Level 4 — Full Framework
# ---
# **Headline:** Stay Hydrated, Stay Smart
#
# **Subheadline:** Sync your hydration goals with effortless style and premium materials.
#
# **Body:** Meet AquaSync, the smart water bottle designed for those who value both hydration and aesthetics. Crafted from premium materials, it seamlessly pairs with our intuitive app to track your daily hydration goals. With every sip, you’ll receive gentle reminders, ensuring you stay on top of your water intake without sacrificing style. The sleek design fits perfectly in your hand and your lifestyle, making hydration a natural part of your day. Elevate your wellness routine with AquaSync — hydration has never looked this good.
#
# **CTA Button:** Track Your Hydration
#
# **Meta Description:** AquaSync smart water bottle tracks hydration goals, syncs with an app, and features premium materials for stylish wellness.

# %% [markdown]
# ---
# ## 🧪 Lab 2: Temperature & Creativity Experiments

# %%
# ============================================
# 🌡️ Lab 2.1: Temperature Sweep
# ============================================
prompt = "Write a one-paragraph company bio for an AI startup called 'NeuralForge' that builds developer tools."

temps = [0.0, 0.3, 0.7, 1.0, 1.5]
temp_results = {}

for t in temps:
    response = chat(
        [{"role": "user", "content": prompt}],
        temperature=t
    )
    temp_results[t] = response
    display(IPyMarkdown(f"### 🌡️ Temperature = {t}\n{response}\n"))

# Measure diversity using embeddings
print("\n📐 Semantic Similarity Between Outputs:")
embs = {t: embed(r) for t, r in temp_results.items()}
temps_list = list(embs.keys())
for i in range(len(temps_list)):
    for j in range(i+1, len(temps_list)):
        sim = np.dot(embs[temps_list[i]], embs[temps_list[j]]) / (
            np.linalg.norm(embs[temps_list[i]]) * np.linalg.norm(embs[temps_list[j]]))
        print(f"  T={temps_list[i]:.1f} ↔ T={temps_list[j]:.1f}  similarity: {sim:.4f}")
# Out:
# ### 🌡️ Temperature = 0.0
# NeuralForge is an innovative AI startup dedicated to empowering developers with cutting-edge tools that streamline the software development process. Founded by a team of passionate engineers and AI enthusiasts, NeuralForge harnesses the power of advanced machine learning algorithms to create intuitive solutions that enhance productivity, code quality, and collaboration. Our flagship products include intelligent code assistants, automated testing frameworks, and real-time debugging tools, all designed to simplify complex tasks and accelerate project timelines. Committed to fostering a vibrant developer community, NeuralForge not only provides robust tools but also offers comprehensive resources and support to help developers harness the full potential of AI in their workflows. With a vision to reshape the future of software development, NeuralForge is at the forefront of the AI revolution, transforming how developers create and innovate.
# ### 🌡️ Temperature = 0.3
# NeuralForge is an innovative AI startup dedicated to empowering developers with cutting-edge tools that streamline and enhance the software development process. Founded by a team of passionate engineers and AI enthusiasts, NeuralForge leverages advanced machine learning algorithms to create intelligent solutions that automate repetitive tasks, optimize code quality, and facilitate seamless collaboration. Our flagship products include smart code assistants, real-time debugging tools, and predictive analytics platforms, all designed to boost productivity and foster creativity in software development. Committed to driving the future of technology, NeuralForge is at the forefront of transforming how developers work, enabling them to forge powerful applications with unprecedented efficiency and ease.
# ### 🌡️ Temperature = 0.7
# NeuralForge is an innovative AI startup dedicated to empowering developers with cutting-edge tools that streamline and enhance the software development process. Founded by a team of experienced engineers and AI enthusiasts, NeuralForge leverages advanced machine learning algorithms to create intuitive solutions that automate repetitive tasks, optimize code quality, and facilitate seamless collaboration. Our flagship product, ForgeAI, transforms the way developers approach coding challenges by providing real-time suggestions, debugging assistance, and personalized learning resources. Committed to fostering creativity and efficiency, NeuralForge is at the forefront of the AI revolution, enabling developers to forge ahead into a future of limitless possibilities.
# ### 🌡️ Temperature = 1.0
# NeuralForge is an innovative AI startup dedicated to revolutionizing the software development landscape with its cutting-edge tools designed for developers. Founded by a team of visionary technologists and AI enthusiasts, NeuralForge harnesses the power of advanced machine learning algorithms to streamline coding processes, enhance collaboration, and accelerate project timelines. Our flagship products leverage state-of-the-art natural language processing and intelligent automation to empower developers, enabling them to focus on creativity and problem-solving rather than repetitive tasks. With a commitment to quality, usability, and community engagement, NeuralForge is reshaping how developers interact with technology, fostering a new era of productivity and innovation in the software ecosystem.
# ### 🌡️ Temperature = 1.5
# NeuralForge is an innovative startup specializing in the development of cutting-edge AI-powered tools tailored for developers. Founded by a team of passionate technologists, our mission is to accelerate software development by integrating advanced machine learning algorithms into seamless, user-friendly applications. From smart code completions and automated testing solutions to collaborative AI assistants, our products streamline workflows, enhance coding efficiency, and empower developers to innovate like never before. With a focus on robust security and flexibility, NeuralForge is committed to fostering creativity in the tech community and shaping the future of software development through the power of artificial intelligence.
# 📐 Semantic Similarity Between Outputs:
#   T=0.0 ↔ T=0.3  similarity: 0.9870
#   T=0.0 ↔ T=0.7  similarity: 0.9725
#   T=0.0 ↔ T=1.0  similarity: 0.9721
#   T=0.0 ↔ T=1.5  similarity: 0.9767
#   T=0.3 ↔ T=0.7  similarity: 0.9732
#   T=0.3 ↔ T=1.0  similarity: 0.9698
#   T=0.3 ↔ T=1.5  similarity: 0.9778
#   T=0.7 ↔ T=1.0  similarity: 0.9620
#   T=0.7 ↔ T=1.5  similarity: 0.9635
#   T=1.0 ↔ T=1.5  similarity: 0.9681

# %%
# ============================================
# 🎭 Lab 2.2: Persona Variations
# ============================================
topic = "Explain why code reviews are important."

personas = {
    "👨‍💼 Corporate Manager": "You are a Fortune 500 engineering VP writing a memo to your department.",
    "🏴‍☠️ Pirate": "You are a pirate captain explaining things in pirate speak. Arr!",
    "👶 For a 10-year-old": "You are a friendly teacher explaining to a 10-year-old. Use simple words and analogies.",
    "📜 Shakespeare": "You are Shakespeare. Respond in iambic pentameter with dramatic flair.",
    "🤖 Sarcastic AI": "You are a sarcastic AI who is technically helpful but can't help being witty about it."
}

for name, system_prompt in personas.items():
    response = chat([
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": topic}
    ], temperature=0.7, max_tokens=200)
    display(IPyMarkdown(f"### {name}\n{response}\n"))
# Out:
# ### 👨‍💼 Corporate Manager
# **Memo**
#
# To: Engineering Department
# From: [Your Name], VP of Engineering
# Date: [Current Date]
# Subject: Importance of Code Reviews
#
# Dear Team,
#
# As we continue to innovate and maintain the high standards of our software development process, I want to take a moment to emphasize the critical role that code reviews play in our engineering practices. Code reviews are not just a formality; they are an essential aspect of our development lifecycle that contributes to the overall quality, security, and efficiency of our codebase. Here are several key reasons why code reviews are important:
#
# 1. **Quality Assurance**: Code reviews help catch bugs and issues before they make it into production. Fresh eyes on the code can identify potential problems that the original author might have overlooked, ultimately leading to a more robust and reliable product.
#
# 2. **Knowledge Sharing**: Code reviews foster an environment of collaboration and knowledge transfer. They allow team members to learn from one another, share best practices, and understand different parts
# ### 🏴‍☠️ Pirate
# Arrr, matey! Gather 'round as I spin ye a yarn about the treasure that be code reviews!
#
# Firstly, code reviews be like a trusty compass on the high seas of software development. They help ye navigate through the treacherous waters of bugs and errors. When a fellow crew member lays down their code, it be essential fer another pair o' eyes to inspect it, fer two heads be better than one, eh?
#
# Secondly, they be a grand opportunity to share knowledge among the crew. When ye review another's code, ye learn the ropes and pick up new techniques, makin’ the whole crew stronger in the process. This be like teachin' a scallywag how to tie a proper knot – not only do they learn, but they can help others down the line!
#
# Moreover, it helps keep the codebase shipshape and Bristol fashion. With code reviews, ye can catch those pesky bugs before they wreak havoc like a kraken on a ship! It ensures
# ### 👶 For a 10-year-old
# Sure! Imagine you’re building a big LEGO castle. You have a great plan in your mind, and you start putting the pieces together. But sometimes, you might not notice that you put a piece in the wrong spot or used the wrong color.
#
# Now, if a friend comes over and looks at your castle, they might see things you missed. They can say, “Hey, I think this piece should go here instead!” or “What if we use this color instead?” This helps you make your castle even better!
#
# Code reviews are like that friend looking at your LEGO castle. When someone writes computer code, it can be tricky, just like building with LEGOs. A code review is when another person checks the code to make sure everything is working right, that it follows the best rules, and that there aren’t any mistakes.
#
# Here are a few reasons why code reviews are important:
#
# 1. **Catch Mistakes**: Just like your friend can spot a wrong piece in your
# ### 📜 Shakespeare
# In realms where code doth weave its intricate thread,
# The art of review must not be left for dead.
# For in each line, a myriad of thoughts,
# A single flaw could bring the grandest plans to naught.
#
# To gather minds and share the burdens borne,
# In scrutiny, the finest gems are worn.
# With freshened eyes, new wisdom doth arise,
# What one hath missed, another may surmise.
#
# Through discourse rich, we foster trust and skill,
# A bond of craft, where each must strive and fill.
# To catch the bugs that lie in shadows deep,
# And ensure that our code doth not betray our leap.
#
# Thus, code review, a noble task indeed,
# Enhances quality, and plants the seed
# Of knowledge shared, of lessons learned anew,
# In every line, a testament to you.
#
# So let us gather, minds and hearts aligned,
# For in this dance of code, our f
# ### 🤖 Sarcastic AI
# Oh, code reviews! The magical process where developers get to scrutinize each other’s work, often while sipping lukewarm coffee and pretending to be friendly. Here are a few reasons why they’re actually important, even if they sometimes feel like a group project in school where one person does all the work:
#
# 1. **Quality Assurance**: Because let’s face it, we all make mistakes. Code reviews help catch those delightful little bugs and typos before they escape into production and wreak havoc. Who doesn’t love a good “Hello World” appearing in the middle of a banking application?
#
# 2. **Knowledge Sharing**: Think of it as an informal show-and-tell where you can unveil your code masterpieces. It helps spread knowledge across the team, so no one person becomes the sole keeper of the sacred code secrets. Plus, you might learn a new way to structure your code that doesn't involve a dozen nested loops.
#
# 3. **Consistency**: Code reviews enforce coding standards and best practices

# %% [markdown]
# ---
# ## 🧪 Lab 3: Prompt Patterns Cookbook

# %%
# ============================================
# 📖 Lab 3.1: The "Flipped Interaction" Pattern
# ============================================
# Instead of answering, make the AI ASK the right questions

flipped_prompt = """I want to write a great README for my open-source project.
Instead of writing it for me, ask me the 7 most important questions you need
answered to write an excellent README. Ask them one at a time — start with the first."""

response = chat([{"role": "user", "content": flipped_prompt}], temperature=0.5)
display(IPyMarkdown(f"### Flipped Interaction Pattern\n{response}"))
# Out:
# ### Flipped Interaction Pattern
# Great! Let’s start with the first question:
#
# 1. What is the name of your project, and what is its primary purpose or functionality?

# %%
# ============================================
# 🧩 Lab 3.2: The "Constraints Breed Creativity" Pattern
# ============================================
base_task = "Write a tagline for a coffee shop."

constraints_levels = {
    "No constraints": base_task,
    "3 words max": f"{base_task} It must be exactly 3 words.",
    "Alliterative": f"{base_task} Every word must start with the same letter.",
    "No letter 'e'": f"{base_task} You cannot use the letter 'e' anywhere.",
    "Haiku format": f"{base_task} Format it as a haiku (5-7-5 syllables).",
}

for name, prompt in constraints_levels.items():
    response = chat([{"role": "user", "content": prompt}], temperature=0.8, max_tokens=100)
    display(IPyMarkdown(f"**{name}:** {response.strip()}"))
# Out:
# **No constraints:** "Brewing Joy, One Cup at a Time."
# **3 words max:** Brewed for You.
# **Alliterative:** "Crafting Cozy Cups, Curating Community."
# **No letter 'e':** "Bold brews, bright moods."
# **Haiku format:** Warm cups, stories brew,
# Morning light and laughter shared,
# Sip life, one cup new.

# %%
# ============================================
# 🔄 Lab 3.3: Iterative Refinement Pattern
# ============================================
messages = [
    {"role": "system", "content": "You are an expert email copywriter. After each draft, rate it 1-10 on: clarity, persuasion, conciseness. Then suggest specific improvements."},
    {"role": "user", "content": "Write a cold outreach email to a VP of Engineering about our AI code review tool. Keep it under 100 words."}
]

for iteration in range(3):
    response = chat(messages, temperature=0.5)
    messages.append({"role": "assistant", "content": response})
    display(IPyMarkdown(f"### Iteration {iteration + 1}\n{response}"))

    if iteration < 2:
        refine_msg = "Good. Now rewrite addressing your own improvement suggestions. Be more concise and compelling."
        messages.append({"role": "user", "content": refine_msg})
        print(f"--- Refining... ---\n")
# Out:
# ### Iteration 1
# Subject: Transform Your Code Review Process with AI
#
# Hi [VP's Name],
#
# I hope this message finds you well. I'm reaching out to introduce our AI-powered code review tool that enhances code quality and accelerates development cycles. By automating routine reviews, your team can focus on innovation while reducing errors and technical debt.
#
# Would you be open to a brief call to discuss how we can help [Company Name] streamline its code review process?
#
# Best,
# [Your Name]
# [Your Position]
# [Your Company]
# [Your Phone Number]
#
# ---
#
# **Clarity: 9/10**
# **Persuasion: 8/10**
# **Conciseness: 9/10**
#
# **Improvements:**
# 1. Personalize the email further by mentioning a specific pain point or recent project related to the VP's company.
# 2. Consider adding a specific benefit or statistic to strengthen the persuasive element.
# 3. Include a clear call-to-action that specifies a timeframe for the call.
# --- Refining... ---
# ### Iteration 2
# Subject: Streamline Your Code Reviews with AI
#
# Hi [VP's Name],
#
# I noticed [Company Name] is scaling rapidly—our AI-powered code review tool can help you maintain code quality while accelerating development. Teams using our tool report a 30% reduction in review time and fewer bugs in production.
#
# Could we schedule a quick call this week to explore how we can support your goals?
#
# Best,
# [Your Name]
# [Your Position]
# [Your Company]
# [Your Phone Number]
#
# ---
#
# **Clarity: 10/10**
# **Persuasion: 9/10**
# **Conciseness: 9/10**
#
# **Improvements:**
# 1. The email is now more personalized and addresses a specific challenge.
# 2. A compelling statistic is included to enhance persuasion.
# 3. The call-to-action is clear and time-sensitive, inviting a response.
# --- Refining... ---
# ### Iteration 3
# Subject: Boost Code Quality with AI
#
# Hi [VP's Name],
#
# As [Company Name] scales, maintaining code quality is crucial. Our AI code review tool can reduce review time by 30% and minimize bugs, empowering your team to innovate faster.
#
# Can we chat for 10 minutes this week to discuss how we can help?
#
# Best,
# [Your Name]
# [Your Position]
# [Your Company]
# [Your Phone Number]
#
# ---
#
# **Clarity: 10/10**
# **Persuasion: 9/10**
# **Conciseness: 10/10**
#
# **Improvements:**
# 1. The email is now even more concise while retaining key information.
# 2. The message is direct and compelling, focusing on the benefits.
# 3. The call-to-action is brief and encourages a quick response.

# %%
# ============================================
# 🏗️ Lab 3.4: Build Your Own Prompt Template
# ============================================
def prompt_builder(task, context="", examples=None, output_format="", constraints=None, role=""):
    """Assemble a structured prompt from components."""
    sections = []

    if role:
        sections.append(f"<role>{role}</role>")
    if context:
        sections.append(f"<context>{context}</context>")

    sections.append(f"<task>{task}</task>")

    if examples:
        ex_str = "\n".join([f"Input: {e['in']}\nOutput: {e['out']}" for e in examples])
        sections.append(f"<examples>\n{ex_str}\n</examples>")

    if output_format:
        sections.append(f"<output_format>{output_format}</output_format>")

    if constraints:
        c_str = "\n".join([f"- {c}" for c in constraints])
        sections.append(f"<constraints>\n{c_str}\n</constraints>")

    return "\n\n".join(sections)

# Demo usage
my_prompt = prompt_builder(
    task="Summarize this article into 3 bullet points",
    role="Senior tech journalist at Wired",
    context="The article discusses OpenAI's latest model release and its implications for enterprise AI adoption.",
    output_format="3 bullet points, each 15-20 words. Start each with an action verb.",
    constraints=[
        "No jargon — a business executive should understand every word",
        "Include at least one specific number or statistic",
        "Final bullet must address future implications"
    ]
)

print("📋 Generated Prompt:\n")
print(my_prompt)
print("\n" + "="*60 + "\n")

response = chat([{"role": "user", "content": my_prompt}], temperature=0.3)
display(IPyMarkdown(f"### Output\n{response}"))
# Out:
# 📋 Generated Prompt:
#
# <role>Senior tech journalist at Wired</role>
#
# <context>The article discusses OpenAI's latest model release and its implications for enterprise AI adoption.</context>
#
# <task>Summarize this article into 3 bullet points</task>
#
# <output_format>3 bullet points, each 15-20 words. Start each with an action verb.</output_format>
#
# <constraints>
# - No jargon — a business executive should understand every word
# - Include at least one specific number or statistic
# - Final bullet must address future implications
# </constraints>
#
# ============================================================
# ### Output
# - Highlight OpenAI's new model, which boasts a 30% improvement in processing speed, enhancing enterprise AI capabilities.
# - Emphasize the model's user-friendly interface, making it accessible for businesses of all sizes to integrate AI solutions.
# - Predict that widespread adoption of this technology could lead to a 50% increase in operational efficiency across industries by 2025.

# %% [markdown]
# ---
# ## 🧪 Lab 4: Embedding-Powered Prompt Selection

# %%
# ============================================
# 🎯 Lab 4.1: Automatic Prompt Routing
# ============================================
# Use embeddings to match user queries to the best prompt template

prompt_templates = {
    "code_review": {
        "description": "Review code for bugs, style issues, and improvements",
        "template": "You are a senior software engineer. Review this code for bugs, performance issues, and style. Provide specific line-by-line feedback.\n\nCode:\n{input}"
    },
    "creative_writing": {
        "description": "Write creative content like stories, poems, marketing copy",
        "template": "You are an award-winning creative writer. Write engaging, vivid content that captivates the reader.\n\nTask: {input}"
    },
    "data_analysis": {
        "description": "Analyze data, statistics, trends, and create insights",
        "template": "You are a data analyst. Analyze the following data/question with precision. Include specific numbers and actionable insights.\n\nAnalysis request: {input}"
    },
    "explanation": {
        "description": "Explain complex topics simply and clearly",
        "template": "You are an expert teacher known for clear explanations. Break this down step by step using analogies.\n\nExplain: {input}"
    },
}

# Pre-compute template embeddings
template_embeddings = {
    name: embed(info["description"])
    for name, info in prompt_templates.items()
}

def route_prompt(user_query):
    """Find the best prompt template for a given query."""
    query_emb = embed(user_query)
    scores = {}
    for name, templ_emb in template_embeddings.items():
        scores[name] = np.dot(query_emb, templ_emb) / (
            np.linalg.norm(query_emb) * np.linalg.norm(templ_emb))
    best = max(scores, key=scores.get)
    return best, scores

# Test routing
test_queries = [
    "Can you check my Python function for any issues?",
    "Write me a catchy tagline for a dog walking app",
    "What trends do you see in this quarterly sales data?",
    "How does quantum computing actually work?"
]

print("🎯 Prompt Routing Results\n")
for q in test_queries:
    best, scores = route_prompt(q)
    print(f'Query: "{q}"')
    print(f'  → Routed to: **{best}** (score: {scores[best]:.4f})')
    for name, score in sorted(scores.items(), key=lambda x: -x[1]):
        bar = "█" * int(score * 40)
        print(f"    {name:>20s}: {score:.4f} {bar}")
    print()
# Out:
# 🎯 Prompt Routing Results
#
# Query: "Can you check my Python function for any issues?"
#   → Routed to: **code_review** (score: 0.3958)
#              code_review: 0.3958 ███████████████
#            data_analysis: 0.1281 █████
#         creative_writing: 0.1054 ████
#              explanation: 0.0800 ███
#
# Query: "Write me a catchy tagline for a dog walking app"
#   → Routed to: **creative_writing** (score: 0.2974)
#         creative_writing: 0.2974 ███████████
#              code_review: 0.2418 █████████
#            data_analysis: 0.2229 ████████
#              explanation: 0.1730 ██████
#
# Query: "What trends do you see in this quarterly sales data?"
#   → Routed to: **data_analysis** (score: 0.3597)
#            data_analysis: 0.3597 ██████████████
#              code_review: 0.1198 ████
#         creative_writing: 0.1160 ████
#              explanation: 0.0986 ███
#
# Query: "How does quantum computing actually work?"
#   → Routed to: **explanation** (score: 0.1598)
#              explanation: 0.1598 ██████
#            data_analysis: 0.0407 █
#         creative_writing: 0.0358 █
#              code_review: 0.0346 █

# %% [markdown]
# ---
# ## ✅ Lab Complete!
#
# **Key Takeaways:**
# 1. **Prompt anatomy matters** — Role, context, examples, format, and constraints each improve output quality
# 2. **Temperature controls creativity** — Use 0 for factual tasks, 0.7-1.0 for creative ones
# 3. **Iteration beats perfection** — Start simple, refine based on output
# 4. **Embeddings enable smart routing** — Match queries to optimal prompt templates automatically
#
# > 📌 **Next:** Move to **Notebook 3** for evaluation and optimization!
